# %% [markdown]
# # Data Collection
#
# In this notebook, we collect mentions to @ML_Ayuda, the MercadoLibre´s twitter account used to solve user´s problems. The data is saved in the folder "_datasets" as a csv file. The tweets from the other accounts are collected using the python script named as "searcher.py", in the same directory.
#
# We use the library Tweepy and an Twitter Developer Account. The keys are hidden for security.

# %%
import tweepy as tw
from pandas import DataFrame
import seaborn as sns

# %%
CONSUMER_KEY = ""
CONSUMER_SECRET = ""
ACCESS_TOKEN = ""
ACCESS_SECRET = ""

# %%
auth = tw.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
userID = "ML_Ayuda"

# %%
data = []

for tweet in tw.Cursor(api.search, q="@ML_Ayuda").items(10000):
    data.append(tweet)

# %%
outtweets = [[tweet.created_at, tweet.user.location, tweet.text] 
             for idx,tweet in enumerate(data)]

# %%
df = DataFrame(outtweets,columns=["date", "location", "text"])
#df.to_csv('%s_tweets.csv' % userID,index=False)

# %%
df.head(20)
# Out:
#                   date             location  \
# 0  2021-02-10 04:01:34
# 1  2021-02-10 04:01:09
# 2  2021-02-10 04:00:06  Paraná - Entre Rios
# 3  2021-02-10 03:59:23
# 4  2021-02-10 03:56:24
# 5  2021-02-10 03:55:21     Ciudad de México
# 6  2021-02-10 03:55:01
# 7  2021-02-10 03:46:08    Las Condes, Chile
# 8  2021-02-10 03:40:11               México
# 9  2021-02-10 03:38:52               México
# 10 2021-02-10 03:38:04               México
# 11 2021-02-10 03:30:06
# 12 2021-02-10 03:28:21
# 13 2021-02-10 03:24:12          Cuajimalpa
# 14 2021-02-10 03:18:26
# 15 2021-02-10 03:16:08             La Plata
# 16 2021-02-10 03:14:21
# 17 2021-02-10 03:13:23
# 18 2021-02-10 03:12:21
# 19 2021-02-10 03:11:36
#
#                                                  text
# 0   @ML_Ayuda me cancelaron mi cuenta, no permitié...
# 1   RT @valeanri: Compre dos impresoras con tremen...
# 2   @ML_Ayuda No, me suspendieron mí cuenta por co...
# 3   RT @valeanri: @jdelrio70 @ML_Ayuda @el_kaluga ...
# ...
